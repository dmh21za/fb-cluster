# %% [markdown]
# <h3>0. Setup</h3>
# <ul>
# <li>Get the environment variables</li>
# </ul>

# %%
import os
from dotenv import load_dotenv
load_dotenv()

CSV_FILE = None
DATA_FILE_LOC = f"{os.getenv('DATA_DIR')}/{os.getenv('DATA_FILENAME')}"

with open(DATA_FILE_LOC, 'r') as f:
    CSV_FILE = f.read()

# %% [markdown]
# <h3>1. First we read the data file as a CSV</h3>

# %%
CSV_FILE = None

# %% [markdown]
# <h3>2. Next we convert the CSV to a DF</h3>

# %% [markdown]
# <h3>3. Now we choose what features we want to extract for now</h3>

# %% [markdown]
# <h3>4. Maybe we add some extra features?</h3>
# <ul>
# <li>Before Senedd Election</li>
# </ul>
